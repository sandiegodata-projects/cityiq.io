# %%
import geopandas as gpd
import pandas as pd
import datetime
from cityiq import Config, CityIq
from cityiq.api import Asset, Location
from cityiq.scrape import EventScraper

# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %%
#pkg = mp.jupyter.open_package()
pkg = mp.jupyter.open_source_package()
pkg
# Out:
# <h1>San Diego City IQ Assets and Locations</h1>
# <p><code>sandiego.gov-cityiq_objects-2</code> Last Update: 2019-02-16T06:33:26</p>
# <p><em>All assets types extracted form the San Diego City Iq system</em></p>
# <p>These datafile are extracts of the assets and locations from the San Diego
# CityIQ system. Refer to the <a href="https://ie-cities-docs.run.aws-usw02-pr.ice.predix.io/#c_overview
#  _of_general_apis.html">CityIQ developer
# documentation</a> for details about these data records. The data are
# extracted using the <a href="https://pypi.org/project/cityiq/">cityiq Python package</a>.
# See the ExtractAssets.ipynb notebook for the extract process.</p>
# <h2>Contacts</h2>
# <ul>
# <li><strong>Wrangler</strong> <a href="mailto:eric@civicknowledge.com">Eric Busboom</a>, <a href="http://civicknowledge.com">Civic Knowledge</a></li>
# </ul>
# <h2>Resources</h2>
# <ul>
# <li><strong> <a href="notebooks/ExtractAssets.ipynb#assets">assets</a></strong>. All assets</li>
# <li><strong> <a href="notebooks/ExtractAssets.ipynb#locations">locations</a></strong>. All locations: walkways, traffic lanes and parking zones</li>
# </ul>
# <h2>References</h2>
# <ul>
# <li><strong><a href="index:sangis.org-roads-sandiego#all_roads">sdroads</a></strong>. Roads in San Diego</li>
# <li><strong><a href="metapack+http://library.metatab.org/sandiegodata.org-geography-2018.csv">geography</a></strong>. San Diego tracts and communities</li>
# </ul>

# %%
locations = pkg.resource('locations').geoframe()
assets = pkg.resource('assets').geoframe()

locations.head()
# Out:
#   locationUid  locationType parentLocationUid roadsegid speed oneway abloaddr  \
# 0    004361eb       WALKWAY          004361eb   40052.0  35.0      T   2100.0
# 1    00456472  TRAFFIC_LANE          00456472   40052.0  35.0      T   2100.0
# 2    0051796c       WALKWAY          0051796c   54946.0  20.0      F   1600.0
# 3    00537bf3  TRAFFIC_LANE          00537bf3   54946.0  20.0      F   1600.0
# 4    005f90ed       WALKWAY          005f90ed   54945.0  20.0      F   1700.0
#
#   abhiaddr      rd30full                                           geometry
# 0   2199.0  KETTNER BLVD  LINESTRING (-117.1706148251287 32.726548905684...
# 1   2199.0  KETTNER BLVD  LINESTRING (-117.1705245131968 32.726558517207...
# 2   1699.0      STATE ST  LINESTRING (-117.1666581391174 32.722214661862...
# 3   1699.0      STATE ST  LINESTRING (-117.166581746989 32.7222178855665...
# 4   1799.0      STATE ST  LINESTRING (-117.1665182431566 32.723810889902...

# %%
assets.head()
# Out:
#                                assetUid assetType  \
# 0  000223ee-a868-474b-abcb-12ff1bad00a3    CAMERA
# 1  0002e3bb-5a9a-4083-9a96-fad0d22877b9       MIC
# 2  0003806e-e409-449f-aab1-fc95f6e88d4e    CAMERA
# 3  000a4ac7-224b-4fb7-a2e2-cd0592d2b2de    CAMERA
# 4  000b2365-5309-422a-9be6-1b7127ca18db      NODE
#
#                          parentAssetUid    mediaType events roadsegid speed  \
# 0  131d67b7-daaf-4252-9202-5df347a6c2a3  IMAGE,VIDEO           1453.0  20.0
# 1  e8beafbf-7836-48c3-bb14-440970eecd6d        AUDIO           3046.0  20.0
# 2  f91ec557-f03e-4189-8b83-5aa8d28fbf14  IMAGE,VIDEO           2270.0  20.0
# 3  741ce488-72fa-4216-a65d-216f7bdf8b7d  IMAGE,VIDEO           3152.0  20.0
# 4                                                             40722.0  20.0
#
#   oneway abloaddr abhiaddr              rd30full  \
# 0      F    500.0    599.0              05TH AVE
# 1      B    400.0    499.0               16TH ST
# 2      B    400.0    499.0              09TH AVE
# 3      B    900.0    999.0               17TH ST
# 4      B   5300.0   5349.0  LA JOLLA HERMOSA AVE
#
#                                      geometry
# 0            POINT (-117.1600173 32.71143062)
# 1            POINT (-117.1493049 32.70997207)
# 2            POINT (-117.1566029 32.70934863)
# 3             POINT (-117.148666 32.71585673)
# 4  POINT (-117.264282290807 32.8105285177251)

# %%
parking = [ e for e in loc_rec if e.locationType == 'PARKING_ZONE']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-b918dcbfa6fa> in <module>
# ----> 1 parking = [ e for e in loc_rec if e.locationType == 'PARKING_ZONE']
#
# NameError: name 'loc_rec' is not defined

# %%
import metapack as mp
pkg = mp.open_package('http://library.metatab.org/sandiegodata.org-geography-2018.csv')
pkg

# %%
tracts = pkg.resource('tract_boundaries').geoframe()
tract_comm =  pkg.resource('tract_communities').dataframe()

# %%
t = gpd.GeoDataFrame(
    [ (e.locationUid, e.geometry) for e in parking],
    columns = ['locationUid','geometry'],
    geometry='geometry')
t.crs = tracts.crs
t['geometry'] = t.geometry.centroid

t = gpd.sjoin(t, tracts)
parking_geo = t.merge(tract_comm, on='geoid').drop(columns=['geometry', 'index_right'])
parking_geo.head()

# %%
parking_geo.to_csv('parking_geo.csv')

# %%
com = pkg.resource('sd_community_boundaries').geoframe()
com.plot()

# %%
com = com.to_crs({'init':'epsg:2875'})
com.plot()

# %%
pkg = mp.jupyter.open_package()
roads = pkg.resource('all_roads').geoframe()

sdroads = roads[(roads.lpsjur == 'SD') | (roads.rpsjur == 'SD')].copy()

# Convert to EPSG:2875 ( California zone 6, feet ) so we can make the buffer in feet
sdroads = sdroads.to_crs({'init':'epsg:2875'})

# Buffer the roads to be big enough to enclose the assets
sdroads['geometry'] = sdroads.geometry.apply(lambda g : g.buffer(60,cap_style=1, join_style=2))
